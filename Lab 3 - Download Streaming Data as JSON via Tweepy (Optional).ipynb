# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# Enter Twitter API Keys
access_token = "1186750306232786944-ELz0hJwuZPkMGJTXiQNkM5zF6ZyBWy"
access_token_secret = "PepuWxmWboOgrz51vt5dLaZbfGDiV3BgeUxKrVbnCGfQt"
consumer_key = "xJL0bk8eWoOin4wi1LUenREhy"
consumer_secret = "C38hPtxrOrUqsKFRgdgsjixI0Oh1GV8EVmdcki6MgLFdcTCBw3"

# Create the class that will handle the tweet stream
class StdOutListener(StreamListener):
      
    def on_data(self, data):   
        print(data)
        return True
        

    def on_error(self, status):
        print(status)


if __name__ == '__main__':  
# Handle Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)
    stream.filter(track=["#Election2020"])  #TODO: Add your hashtags here
# Out:
# {"created_at":"Thu Oct 08 00:53:10 +0000 2020","id":1314005883303665664,"id_str":"1314005883303665664","text":"RT @Corey_Feldman: ASK ABOUT THE CHILDREN IN #DEBATES2020 @POTUS @JoeBiden DONT FEAR THE REAPER! ANSWER THE QUESTION ALL AMERICANS R REALLY\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1283260124698558464,"id_str":"1283260124698558464","name":"MakingGodsLoveFamous","screen_name":"GodsLoveFamous","location":"California, USA","url":"http:\/\/www.makeGodslovefamous.com","description":"Christs return is upon us! #makeGodslovefamous Happily married and enjoying whatever time we have left! Spending my time sharing GODS love with others!","translator_type":"none","protected":false,"verified":false,"followers_count":7414
# ...

# %% [markdown]
# Go to https://jsonlint.com/. Copy and paste the text into the web UI to view json data in a formatted way.
